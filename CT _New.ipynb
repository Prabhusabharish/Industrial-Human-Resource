# %%
# !pip install pandas

# %%
import pandas as pd
import numpy as np
# Out:
# C:\Users\prabh\AppData\Local\Temp\ipykernel_12824\2162656668.py:1: DeprecationWarning:
# Pyarrow will become a required dependency of pandas in the next major release of pandas (pandas 3.0),
# (to allow more performant data types, such as the Arrow string type, and better interoperability with other libraries)
# but was not found to be installed on your system.
# If this would cause problems for you,
# please provide us feedback at https://github.com/pandas-dev/pandas/issues/54466
#
#   import pandas as pd

# %%
df1 = pd.read_csv("C:/Users/prabh/Downloads/Datascience/Project/CT/DataSets/DDW_B18_0800_NIC_FINAL_STATE_RAJASTHAN-2011.csv", encoding='latin1')
df2 = pd.read_csv("C:/Users/prabh/Downloads/Datascience/Project/CT/DataSets/DDW_B18_1200_NIC_FINAL_STATE_ARUNACHAL_PRADESH-2011.csv", encoding='latin1')
df3 = pd.read_csv("C:/Users/prabh/Downloads/Datascience/Project/CT/DataSets/DDW_B18_1400_NIC_FINAL_STATE_MANIPUR-2011.csv", encoding='latin1')
df4 = pd.read_csv("C:/Users/prabh/Downloads/Datascience/Project/CT/DataSets/DDW_B18_1500_NIC_FINAL_STATE_MIZORAM-2011.csv", encoding='latin1')
df5 = pd.read_csv("C:/Users/prabh/Downloads/Datascience/Project/CT/DataSets/DDW_B18_1900_NIC_FINAL_STATE_WEST_BENGAL-2011.csv", encoding='latin1')
df6 = pd.read_csv("C:/Users/prabh/Downloads/Datascience/Project/CT/DataSets/DDW_B18sc_0700_NIC_FINAL_STATE_NCT_OF_DELHI-2011.csv", encoding='latin1')
df7 = pd.read_csv("C:/Users/prabh/Downloads/Datascience/Project/CT/DataSets/DDW_B18sc_1600_NIC_FINAL_STATE_TRIPURA-2011.csv", encoding='latin1')
df8 = pd.read_csv("C:/Users/prabh/Downloads/Datascience/Project/CT/DataSets/DDW_B18sc_2000_NIC_FINAL_STATE_JHARKHAND-2011.csv", encoding='latin1')
df9 = pd.read_csv("C:/Users/prabh/Downloads/Datascience/Project/CT/DataSets/DDW_B18sc_2400_NIC_FINAL_STATE_GUJARAT-2011.csv", encoding='latin1')
df10 = pd.read_csv("C:/Users/prabh/Downloads/Datascience/Project/CT/DataSets/DDW_B18sc_2700_NIC_FINAL_STATE_MAHARASHTRA-2011.csv", encoding='latin1')
df11 = pd.read_csv("C:/Users/prabh/Downloads/Datascience/Project/CT/DataSets/DDW_B18sc_2900_NIC_FINAL_STATE_KARNATAKA-2011.csv", encoding='latin1')
df12 = pd.read_csv("C:/Users/prabh/Downloads/Datascience/Project/CT/DataSets/DDW_B18sc_3000_NIC_FINAL_STATE_GOA-2011.csv", encoding='latin1')
df13 = pd.read_csv("C:/Users/prabh/Downloads/Datascience/Project/CT/DataSets/DDW_B18sc_3200_NIC_FINAL_STATE_KERALA-2011.csv", encoding='latin1')
df14 = pd.read_csv("C:/Users/prabh/Downloads/Datascience/Project/CT/DataSets/DDW_B18sc_3300_NIC_FINAL_STATE_TAMIL_NADU-2011.csv", encoding='latin1')
df15 = pd.read_csv("C:/Users/prabh/Downloads/Datascience/Project/CT/DataSets/DDW_B18sc_3400_NIC_FINAL_STATE_PUDUCHERRY-2011.csv", encoding='latin1')
df16 = pd.read_csv("C:/Users/prabh/Downloads/Datascience/Project/CT/DataSets/DDW_B18st_0200_NIC_FINAL_STATE_HIMACHAL_PRADESH-2011.csv", encoding='latin1')
df17 = pd.read_csv("C:/Users/prabh/Downloads/Datascience/Project/CT/DataSets/DDW_B18st_0500_NIC_FINAL_STATE_UTTARAKHAND-2011.csv", encoding='latin1')
df18 = pd.read_csv("C:/Users/prabh/Downloads/Datascience/Project/CT/DataSets/DDW_B18st_0900_NIC_FINAL_STATE_UTTAR_PRADESH-2011.csv", encoding='latin1')
df19 = pd.read_csv("C:/Users/prabh/Downloads/Datascience/Project/CT/DataSets/DDW_B18st_1000_NIC_FINAL_STATE_BIHAR-2011.csv", encoding='latin1')
df20 = pd.read_csv("C:/Users/prabh/Downloads/Datascience/Project/CT/DataSets/DDW_B18st_1100_NIC_FINAL_STATE_SIKKIM-2011.csv", encoding='latin1')
df21 = pd.read_csv("C:/Users/prabh/Downloads/Datascience/Project/CT/DataSets/DDW_B18st_1300_NIC_FINAL_STATE_NAGALAND-2011.csv", encoding='latin1')
df22 = pd.read_csv("C:/Users/prabh/Downloads/Datascience/Project/CT/DataSets/DDW_B18st_1800_NIC_FINAL_STATE_ASSAM-2011.csv", encoding='latin1')
df23 = pd.read_csv("C:/Users/prabh/Downloads/Datascience/Project/CT/DataSets/DDW_B18st_2100_NIC_FINAL_STATE_ODISHA-2011.csv", encoding='latin1')

# %%
df = pd.concat([df1, df2, df3, df4, df5, df6, df7, df8, df9, df10, df11, df12, df13, df14, df15, df16, df17, df18, df19, df20, df21, df22, df23])
df.head()

# %%
df.to_csv("ResaleFlatPrices_combaine.csv", index= False)

# %%
# remove unnec comma, semi colon,
df['State Code'] = df['State Code'].astype(str).str.replace('`', '').astype(int)
df['District Code'] = df['District Code'].astype(str).str.replace('`', '').astype(int)
df['Division'] = df['Division'].astype(str).str.replace('`', '').astype(int)
df['Group'] = df['Group'].astype(str).str.replace('`', '').astype(int)
df['Class'] = df['Class'].astype(str).str.replace('`', '').astype(int)

# %%
df.columns

# %%
# remove spl char

def remove_sp_char(column_name):
    return ''.join(e for e in column_name if e.isalnum() or e in ('_', '.'))

df.columns = [remove_sp_char(col) for col in df.columns]

# %%
df.columns

# %%
df.head()

# %% [markdown]
# # EDA

# %%
non_numeric_columns =df.select_dtypes(exclude=[float, int]).columns

# Drop non-numeric columns from the DataFrame
numeric_df = df.drop(columns=non_numeric_columns)

# Calculate correlation
correlation_matrix = numeric_df.corr()
correlation_matrix
# Out:
#                              StateCode  DistrictCode  Division     Group  \
# StateCode                     1.000000      0.851207 -0.010642 -0.001695
# DistrictCode                  0.851207      1.000000 -0.005517 -0.005349
# Division                     -0.010642     -0.005517  1.000000  0.744991
# Group                        -0.001695     -0.005349  0.744991  1.000000
# Class                         0.003277     -0.004001  0.438274  0.593097
# MainWorkersTotalPersons      -0.003645     -0.028298 -0.010332 -0.014413
# MainWorkersTotalMales        -0.004775     -0.027999 -0.010797 -0.014439
# MainWorkersTotalFemales       0.001599     -0.027503 -0.007516 -0.013226
# MainWorkersRuralPersons      -0.004710     -0.028544 -0.013753 -0.016427
# MainWorkersRuralMales        -0.005690     -0.028156 -0.013073 -0.015752
# MainWorkersRuralFemales      -0.000498     -0.027300 -0.015046 -0.017440
# MainWorkersUrbanPersons      -0.002714     -0.027413 -0.007376 -0.012471
# ...

# %%
df.shape
# Out:
# (195145, 25)

# %%
df.head()
# Out:
#    StateCode  DistrictCode        IndiaStates  Division  Group  Class  \
# 0          8             0  STATE - RAJASTHAN         0      0      0
# 1          8             0  STATE - RAJASTHAN         1      0      0
# 2          8             0  STATE - RAJASTHAN         1     11      0
# 3          8             0  STATE - RAJASTHAN         1     11    111
# 4          8             0  STATE - RAJASTHAN         1     11    112
#
#                                              NICName  MainWorkersTotalPersons  \
# 0                                              Total                  9017944
# 1  Crop and animal production, hunting and relate...                   450766
# 2                     Growing of non-perennial crops                    12876
# 3  Growing of cereals (except rice), leguminous c...                    12061
# 4                                    Growing of rice                       79
#
#    MainWorkersTotalMales  MainWorkersTotalFemales  ...  \
# ...

# %%
df.isna().sum()
# Out:
# StateCode                      0
# DistrictCode                   0
# IndiaStates                    0
# Division                       0
# Group                          0
# Class                          0
# NICName                        0
# MainWorkersTotalPersons        0
# MainWorkersTotalMales          0
# MainWorkersTotalFemales        0
# MainWorkersRuralPersons        0
# MainWorkersRuralMales          0
# MainWorkersRuralFemales        0
# MainWorkersUrbanPersons        0
# MainWorkersUrbanMales          0
# MainWorkersUrbanFemales        0
# MarginalWorkersTotalPersons    0
# MarginalWorkersTotalMales      0
# MarginalWorkersTotalFemales    0
# MarginalWorkersRuralPersons    0
# MarginalWorkersRuralMales      0
# MarginalWorkersRuralFemales    0
# MarginalWorkersUrbanPersons    0
# MarginalWorkersUrbanMales      0
# MarginalWorkersUrbanFemales    0
# dtype: int64

# %%
df.describe().T
# Out:
#                                 count         mean           std  min    25%  \
# StateCode                    195145.0    19.178278      9.057612  2.0   10.0
# DistrictCode                 195145.0   332.223377    196.176206  0.0  153.0
# Division                     195145.0    46.590351     28.800311  0.0   23.0
# Group                        195145.0   389.422404    313.186034  0.0  103.0
# Class                        195145.0  2293.804709   3059.131669  0.0    0.0
# MainWorkersTotalPersons      195145.0  1492.137518  45681.690979  0.0    6.0
# MainWorkersTotalMales        195145.0  1193.171150  37739.170774  0.0    6.0
# MainWorkersTotalFemales      195145.0   298.966369   8582.018644  0.0    0.0
# MainWorkersRuralPersons      195145.0   660.618719  20444.364940  0.0    2.0
# MainWorkersRuralMales        195145.0   517.035312  16542.946109  0.0    1.0
# MainWorkersRuralFemales      195145.0   143.583407   4314.446369  0.0    0.0
# ...

# %%
df.nunique()
# Out:
# StateCode                        23
# DistrictCode                    472
# IndiaStates                     491
# Division                         89
# Group                           241
# Class                           423
# NICName                         587
# MainWorkersTotalPersons        8679
# MainWorkersTotalMales          7811
# MainWorkersTotalFemales        3970
# MainWorkersRuralPersons        5767
# MainWorkersRuralMales          5218
# MainWorkersRuralFemales        2694
# MainWorkersUrbanPersons        6561
# MainWorkersUrbanMales          5934
# MainWorkersUrbanFemales        2929
# MarginalWorkersTotalPersons    4208
# MarginalWorkersTotalMales      3181
# MarginalWorkersTotalFemales    2850
# MarginalWorkersRuralPersons    3406
# MarginalWorkersRuralMales      2535
# MarginalWorkersRuralFemales    2379
# MarginalWorkersUrbanPersons    2421
# MarginalWorkersUrbanMales      1951
# MarginalWorkersUrbanFemales    1557
# dtype: int64

# %%
import seaborn as sns
import matplotlib.pyplot as plt   
sns.histplot(x = 'IndiaStates', data = df, )
plt.show()

# %%
x_var = "MarginalWorkersTotalPersons"
y_var = "MainWorkersTotalPersons"
sns.boxplot(x = x_var, y = y_var, data = df)
plt.show()

# %%
y_var = "MainWorkersTotalPersons".strip()
sns.scatterplot(x = 'StateCode', y = y_var, data = df)
plt.xlabel('StateCode')
plt.ylabel('NumberofMainWorkers')
plt.title(' StateCode')
plt.show()

# %%
sns.boxplot( x = "NICName", y = 'MarginalWorkersTotalPersons', data = df)
plt.show()

# %% [markdown]
# # Datas cleaning procedures

# %%
df.duplicated()
# Out:
# 0        False
# 1        False
# 2        False
# 3        False
# 4        False
#          ...
# 12042    False
# 12043    False
# 12044    False
# 12045    False
# 12046    False
# Length: 195145, dtype: bool

# %%
df.dtypes
# Out:
# StateCode                       int32
# DistrictCode                    int32
# IndiaStates                    object
# Division                        int32
# Group                           int32
# Class                           int32
# NICName                        object
# MainWorkersTotalPersons         int64
# MainWorkersTotalMales           int64
# MainWorkersTotalFemales         int64
# MainWorkersRuralPersons         int64
# MainWorkersRuralMales           int64
# MainWorkersRuralFemales         int64
# MainWorkersUrbanPersons         int64
# MainWorkersUrbanMales           int64
# MainWorkersUrbanFemales         int64
# MarginalWorkersTotalPersons     int64
# MarginalWorkersTotalMales       int64
# MarginalWorkersTotalFemales     int64
# MarginalWorkersRuralPersons     int64
# MarginalWorkersRuralMales       int64
# MarginalWorkersRuralFemales     int64
# MarginalWorkersUrbanPersons     int64
# MarginalWorkersUrbanMales       int64
# MarginalWorkersUrbanFemales     int64
# ...

# %%
# Drop un nec cols
columns_to_drop = ["StateCode", "DistrictCode", "Division", "Group", "Class"]
df = df.drop(columns=columns_to_drop)

# %%
df.columns
# Out:
# Index(['IndiaStates', 'NICName', 'MainWorkersTotalPersons',
#        'MainWorkersTotalMales', 'MainWorkersTotalFemales',
#        'MainWorkersRuralPersons', 'MainWorkersRuralMales',
#        'MainWorkersRuralFemales', 'MainWorkersUrbanPersons',
#        'MainWorkersUrbanMales', 'MainWorkersUrbanFemales',
#        'MarginalWorkersTotalPersons', 'MarginalWorkersTotalMales',
#        'MarginalWorkersTotalFemales', 'MarginalWorkersRuralPersons',
#        'MarginalWorkersRuralMales', 'MarginalWorkersRuralFemales',
#        'MarginalWorkersUrbanPersons', 'MarginalWorkersUrbanMales',
#        'MarginalWorkersUrbanFemales'],
#       dtype='object')

# %%
# Extract 'State' and 'District' from 'India/States' column
df[['State', 'District']] = df['IndiaStates'].str.extract(r'STATE - (\w+)|District - (\w+)', expand=True)
df = df.drop('IndiaStates', axis=1)

# %%
df[['State', 'District']].isnull().sum()
# Out:
# State       180430
# District     14715
# dtype: int64

# %%
# Fill NaN values in 'State' column with forward fill (ffill)
df['State'] = df['State'].ffill()
df['District'] = df['District'].bfill()

# %%
df[['State', 'District']].isnull().sum()
# Out:
# State       0
# District    0
# dtype: int64

# %%
# # download cleaned df

# df.to_csv("HRM.csv", index = False)

# %% [markdown]
# # Feature Engrr

# %%
# Example: Creating a new 'TotalWorkers' column by summing 'MainWorkersTotalPersons' and 'MarginalWorkersTotalPersons'
df['TotalWorkers'] = df['MainWorkersTotalPersons'] + df['MarginalWorkersTotalPersons']
df['MaleFemaleRatio'] = df['MainWorkersTotalMales'] / (df['MainWorkersTotalFemales'].replace(0, 1))

# %%
df[['TotalWorkers', 'MaleFemaleRatio']].isnull().sum()
# Out:
# TotalWorkers       0
# MaleFemaleRatio    0
# dtype: int64

# %% [markdown]
# # Geo maps creation

# %%
# Replace 'file_path' with the path to your CSV file
file_path = r'C:/Users/prabh/Downloads/Datascience/Project/CT/lat_long.csv'

df1 = pd.read_csv(file_path)

# %%
df1.nunique()
# Out:
# Unnamed: 0    33
# State.Name    33
# latitude      33
# longitude     32
# dtype: int64

# %%
# Concatenate the two DataFrames horizontally (along columns) based on their index
df = pd.concat([df, df1[['latitude', 'longitude']]], axis=1)

# %%
df.columns
# Out:
# Index(['NICName', 'MainWorkersTotalPersons', 'MainWorkersTotalMales',
#        'MainWorkersTotalFemales', 'MainWorkersRuralPersons',
#        'MainWorkersRuralMales', 'MainWorkersRuralFemales',
#        'MainWorkersUrbanPersons', 'MainWorkersUrbanMales',
#        'MainWorkersUrbanFemales', 'MarginalWorkersTotalPersons',
#        'MarginalWorkersTotalMales', 'MarginalWorkersTotalFemales',
#        'MarginalWorkersRuralPersons', 'MarginalWorkersRuralMales',
#        'MarginalWorkersRuralFemales', 'MarginalWorkersUrbanPersons',
#        'MarginalWorkersUrbanMales', 'MarginalWorkersUrbanFemales', 'State',
#        'District', 'TotalWorkers', 'MaleFemaleRatio', 'latitude', 'longitude'],
#       dtype='object')

# %%
df[['latitude', 'longitude', ]].isnull().sum()
# Out:
# latitude     194386
# longitude    194386
# dtype: int64

# %%
df.duplicated()
# Out:
# 0        False
# 1        False
# 2        False
# 3        False
# 4        False
#          ...
# 12042    False
# 12043    False
# 12044     True
# 12045    False
# 12046     True
# Length: 195145, dtype: bool

# %%
# Calculate the mean of the 'Latitude' and 'Longitude' columns
mean_latitude = df['latitude'].mean()
mean_longitude = df['longitude'].mean()

# Fill the missing values with their respective mean values
df.loc[:, 'latitude'] = df['latitude'].fillna(mean_latitude)
df.loc[:, 'longitude'] = df['longitude'].fillna(mean_longitude)

# %%
df[['latitude', 'longitude']].isnull().sum()
# Out:
# latitude     0
# longitude    0
# dtype: int64

# %% [markdown]
# # Outlieres find

# %%
# Select only the numerical columns for outlier detection
numerical_columns = ['MainWorkersTotalPersons', 'MainWorkersTotalMales', 'MainWorkersTotalFemales',
                     'MainWorkersRuralPersons', 'MainWorkersRuralMales', 'MainWorkersRuralFemales',
                     'MainWorkersUrbanPersons', 'MainWorkersUrbanMales', 'MainWorkersUrbanFemales',
                     'MarginalWorkersTotalPersons', 'MarginalWorkersTotalMales', 'MarginalWorkersTotalFemales',
                     'MarginalWorkersRuralPersons', 'MarginalWorkersRuralMales', 'MarginalWorkersRuralFemales',
                     'MarginalWorkersUrbanPersons', 'MarginalWorkersUrbanMales', 'MarginalWorkersUrbanFemales',
                     'TotalWorkers', 'MaleFemaleRatio']

# Calculate outliers using Z-score
z_scores =df[numerical_columns].apply(lambda x: (x - x.mean()) / x.std())

# Set a threshold for Z-score (e.g., 3) to identify outliers
threshold = 3
outliers = (z_scores > threshold) | (z_scores < -threshold)

# Plot Box Plots to visualize the distribution and outliers
plt.figure(figsize=(12, 8))
df[numerical_columns].boxplot()
plt.title("Box Plot of Numerical Columns")
plt.xticks(rotation=90)
plt.show()

# Plot Box Plots separately for each numerical column to focus on individual distributions
for column in numerical_columns:
    plt.figure(figsize=(6, 4))
    df[[column]].boxplot()
    plt.title(f"Box Plot of {column}")
    plt.show()

# %%
# Remove outliers

# Select only the numerical columns for outlier detection
numerical_columns = ['MainWorkersTotalPersons', 'MainWorkersTotalMales', 'MainWorkersTotalFemales',
                     'MainWorkersRuralPersons', 'MainWorkersRuralMales', 'MainWorkersRuralFemales',
                     'MainWorkersUrbanPersons', 'MainWorkersUrbanMales', 'MainWorkersUrbanFemales',
                     'MarginalWorkersTotalPersons', 'MarginalWorkersTotalMales', 'MarginalWorkersTotalFemales',
                     'MarginalWorkersRuralPersons', 'MarginalWorkersRuralMales', 'MarginalWorkersRuralFemales',
                     'MarginalWorkersUrbanPersons', 'MarginalWorkersUrbanMales', 'MarginalWorkersUrbanFemales',
                     'TotalWorkers', 'MaleFemaleRatio']

# Calculate Z-scores for each numerical column
z_scores = df[numerical_columns].apply(lambda x: (x - x.mean()) / x.std())

# Set a threshold for Z-score (e.g., 3) to identify outliers
threshold = 3
outliers = (z_scores > threshold) | (z_scores < -threshold)

# Remove rows with outliers in any numerical column
df1 = df[~outliers.any(axis=1)]

# Visualize the distribution of cleaned data with Box Plots
plt.figure(figsize=(12, 8))
df1[numerical_columns].boxplot()
plt.title("Box Plot of Numerical Columns (After Removing Outliers)")
plt.xticks(rotation=90)
plt.show()

# %%
df1.shape
# Out:
# (191481, 25)

# %%
df.shape
# Out:
# (195145, 25)

# %%
df1.columns

# %%
df1.info()

# %%
df1.nunique()

# %%
df1.to_csv("newdf.csv", index = False)

# %% [markdown]
# # NLP

# %%
# new df1
df2 = pd.read_csv("C:/Users/prabh/Downloads/Datascience/Project/CT/newdf.csv")
df2.head(2)
# Out:
#          IndiaStates                                            NICName  \
# 0  STATE - RAJASTHAN                     Growing of non-perennial crops
# 1  STATE - RAJASTHAN  Growing of cereals (except rice), leguminous c...
#
#    MainWorkersTotalPersons  MainWorkersTotalMales  MainWorkersTotalFemales  \
# 0                    12876                  10547                     2329
# 1                    12061                   9911                     2150
#
#    MainWorkersRuralPersons  MainWorkersRuralMales  MainWorkersRuralFemales  \
# 0                     5644                   4328                     1316
# 1                     5195                   3987                     1208
#
#    MainWorkersUrbanPersons  MainWorkersUrbanMales  ...  \
# 0                     7232                   6219  ...
# 1                     6866                   5924  ...
#
#    MarginalWorkersRuralPersons  MarginalWorkersRuralMales  \
# 0                         8147                       3295
# ...

# %%
df2.columns.tolist()
# Out:
# ['IndiaStates',
#  'NICName',
#  'MainWorkersTotalPersons',
#  'MainWorkersTotalMales',
#  'MainWorkersTotalFemales',
#  'MainWorkersRuralPersons',
#  'MainWorkersRuralMales',
#  'MainWorkersRuralFemales',
#  'MainWorkersUrbanPersons',
#  'MainWorkersUrbanMales',
#  'MainWorkersUrbanFemales',
#  'MarginalWorkersTotalPersons',
#  'MarginalWorkersTotalMales',
#  'MarginalWorkersTotalFemales',
#  'MarginalWorkersRuralPersons',
#  'MarginalWorkersRuralMales',
#  'MarginalWorkersRuralFemales',
#  'MarginalWorkersUrbanPersons',
#  'MarginalWorkersUrbanMales',
#  'MarginalWorkersUrbanFemales',
#  'TotalWorkers',
#  'MaleFemaleRatio',
#  'latitude',
#  'longitude']

# %%
from sklearn.feature_extraction.text import TfidfVectorizer
from sklearn.feature_extraction.text import CountVectorizer
import numpy as np
from sklearn.feature_extraction.text import TfidfVectorizer
from sklearn.decomposition import PCA
from sklearn.cluster import MiniBatchKMeans
from sklearn.metrics import silhouette_score

# %%
# Combine 'NICName' and 'IndiaStates' columns into a single column
df2['text_data'] = df2['NICName'] + ' ' + df2['IndiaStates']

# Initialize TfidfVectorizer
tfidf_vectorizer = TfidfVectorizer()

# Fit and transform the text data into TF-IDF representation
tfidf_matrix = tfidf_vectorizer.fit_transform(df2['text_data'])

# Convert the TF-IDF matrix to a DataFrame
tfidf_df = pd.DataFrame(tfidf_matrix.toarray(), columns=tfidf_vectorizer.get_feature_names_out())

# %%
# Combine 'NICName' and 'IndiaStates' columns into a single column
df2['text_data'] = df2['NICName'] + ' ' + df2['IndiaStates']

# Initialize CountVectorizer
count_vectorizer = CountVectorizer()

# Fit and transform the text data into BoW representation
bow_matrix = count_vectorizer.fit_transform(df2['text_data'])

# Convert the BoW matrix to a DataFrame
bow_df = pd.DataFrame(bow_matrix.toarray(), columns=count_vectorizer.get_feature_names_out())

# %%
# Combine 'NICName' and 'IndiaStates' columns into a single column
df2['text_data'] = df2['NICName'] + ' ' + df2['IndiaStates']

# Convert text data into numerical vectors using TfidfVectorizer
vectorizer = TfidfVectorizer(stop_words='english')
X_tfidf = vectorizer.fit_transform(df2['text_data'])

# Apply PCA to reduce dimensionality of the TF-IDF vectors
pca = PCA(n_components=1)  # You can adjust the number of components as needed
X_pca = pca.fit_transform(X_tfidf.toarray())

# Apply MiniBatchKMeans clustering to group similar businesses based on PCA-transformed data
num_clusters = 5  # You can adjust the number of clusters as needed
kmeans = MiniBatchKMeans(n_clusters=num_clusters, random_state=42)
kmeans.fit(X_pca)

# Get cluster assignments for each data point
df2['Cluster'] = kmeans.labels_

# Evaluate the clustering performance using silhouette score
silhouette_avg = silhouette_score(X_pca, kmeans.labels_)
print(f'Silhouette Score: {silhouette_avg}')

# Display the top terms (features) for each cluster
order_centroids = kmeans.cluster_centers_.argsort()[:, ::-1]
terms = vectorizer.get_feature_names_out()  # Use get_feature_names_out() instead of get_feature_names()
for i in range(num_clusters):
    print(f"Cluster {i+1} Top Terms:", [terms[ind] for ind in order_centroids[i, :5]])

# Example: Print samples from each cluster
for i in range(num_clusters):
    print(f"\nCluster {i+1} Test Samples:")
    test_samples = df2.iloc[np.where(kmeans.predict(X_pca) == i)]
    print(test_samples.head())
# Out:
# Silhouette Score: 0.7068375672931478
# Cluster 1 Top Terms: ['accessories']
# Cluster 2 Top Terms: ['accessories']
# Cluster 3 Top Terms: ['accessories']
# Cluster 4 Top Terms: ['accessories']
# Cluster 5 Top Terms: ['accessories']
#
# Cluster 1 Test Samples:
#           IndiaStates                                           NICName  \
# 25  STATE - RAJASTHAN            Support activities for crop production
# 26  STATE - RAJASTHAN          Support activities for animal production
# 27  STATE - RAJASTHAN                      Post-harvest crop activities
# 29  STATE - RAJASTHAN  Hunting, trapping and related service activities
# 30  STATE - RAJASTHAN  Hunting, trapping and related service activities
#
#     MainWorkersTotalPersons  MainWorkersTotalMales  MainWorkersTotalFemales  \
# 25                    12433                   9573                     2860
# 26                      851                    302                      549
# ...

# %%
df2.to_csv("final_HR.csv", index = False)
